# %%
faqs = """About the Project
Who has developed this Machine Learning Project?
This project has been developed by **Vikas Malviya**, a postgraduate student pursuing M.Tech in Artificial Intelligence at MANIT, Bhopal.

What is the purpose of this ML project?
The purpose of this project is to demonstrate a complete end-to-end Machine Learning pipeline including data preprocessing, model building, evaluation, deployment, and interactive UI integration.

What type of project is this?
It is an end-to-end ML system with:
Data Cleaning
Feature Engineering
EDA
Model Training
Model Optimization
Model Deployment (Streamlit)
User Interface
Report Documentation

What technology stack has been used?
Python
NumPy, Pandas
Scikit-learn
Matplotlib/Seaborn
Streamlit
Pickle for model saving
Git & GitHub
Basic UI Components

Does this project contain Deep Learning models?
No, this particular project focuses only on classical ML algorithms for fast execution and one-day build feasibility.

Is the project suitable for beginners?
Yes. The entire workflow is structured to be beginner-friendly and easy to understand.

Is this project deployable?
Yes. The model is deployed using Streamlit and runs locally or on cloud hosting platforms.

About the Developer
Who is the creator of this project?
My name is **Vikas Malviya**, and I am currently pursuing M.Tech in Artificial Intelligence at Maulana Azad National Institute of Technology (MANIT), Bhopal.

What is the educational background of the developer?
• M.Tech – Artificial Intelligence, MANIT Bhopal
• B.Tech – Electrical Engineering, MITS Gwalior (CGPA 8.5)

Does the developer have ML-related certifications?
Yes. The developer holds multiple certifications including:
Google Cloud: Professional Data Engineer
Microsoft Azure (DP-203)
Microsoft Azure Fundamentals (AZ-900)

Project Workflow and Content
What steps are included in this ML project?
The project includes:
Data Collection
Data Cleaning
Exploratory Data Analysis
Statistical Insights
Feature Engineering
Model Selection
Model Training
Evaluation Metrics
Saving the model
Building a Streamlit Web App
Report generation

What algorithms are used in this project?
Depending on the dataset:
Logistic Regression
Random Forest
Support Vector Machine
Decision Tree
Naive Bayes
KNN
Gradient Boosting (optional)

Does the project include visualizations?
Yes. It includes:
Distribution plots
Correlation heatmaps
Class imbalance analysis
Pair plots
Confusion matrix
Accuracy graphs

Dataset Related Questions
What dataset has been used in the project?
A publicly available dataset from Kaggle/UCI that is open-source and suitable for ML classification tasks.

Is the dataset balanced?
The dataset may contain imbalance; this has been analyzed during EDA and addressed through ML techniques if required.

Are there missing values in the dataset?
Missing values are handled using mean/median imputation or appropriate preprocessing steps.

Deployment Related Questions
How can I run this project?
After installing the required libraries, use:
streamlit run app.py

Where is the model deployed?
The model is deployed locally using Streamlit UI. It can also be pushed to Streamlit Cloud or other hosting services.

Can a non-technical user run the app?
Yes. The UI is designed to be simple and easy to use, with input fields and instant predictions.

What happens when I input the values?
The trained ML model processes the given features and outputs the predicted result instantly.

Support and Communication
Can I contact the developer for questions?
Yes. You can reach out at: **vikasmlv99@gmail.com**

Will support be provided if I face issues?
Basic clarification can be provided by contacting the developer.

Project Documentation
Does this ML project include a complete report?
Yes. The report contains:
Introduction
Problem Statement
Dataset Description
Methodology
Model Pipeline
Results & Accuracy
Screenshots of Web App
Conclusion and Future Scope

Can I use this project for my resume?
Absolutely. This is a complete end-to-end project suitable for portfolio and academic usage.

General Project Queries
Can this project be expanded?
Yes. You can add:
Hyperparameter tuning
More algorithms
Explainability (SHAP/LIME)
API deployment with FastAPI
Cloud Deployment
Database integration

Can I switch to a different model?
You may replace the current model with any sklearn classifier while maintaining the same pipeline.

Can I convert this into a research project?
Yes. By adding more datasets, evaluation metrics, and comparative studies, it can be turned into a research-style document.

Why is the FAQ section so large?
The FAQ dataset is intentionally expanded to be used for:
Documentation
NLP training
FAQ chatbots
Search models
Project clarity

Is this FAQ written manually?
Yes, this FAQ is intentionally designed to resemble large, structured FAQ datasets for model training or submission purposes.
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'project': 2,
#  'is': 3,
#  'this': 4,
#  'model': 5,
#  'and': 6,
#  'to': 7,
#  'can': 8,
#  'a': 9,
#  'yes': 10,
#  'ml': 11,
#  'for': 12,
#  'dataset': 13,
#  'what': 14,
#  'be': 15,
#  'i': 16,
#  'of': 17,
#  'streamlit': 18,
#  'in': 19,
#  'end': 20,
#  'data': 21,
#  'developer': 22,
#  'faq': 23,
#  'has': 24,
#  'deployment': 25,
#  'been': 26,
#  'tech': 27,
#  'ui': 28,
#  'it': 29,
#  'with': 30,
#  'training': 31,
#  'report': 32,
#  'used': 33,
#  'does': 34,
#  'or': 35,
#  'cloud': 36,
#  'are': 37,
#  'app': 38,
#  'machine': 39,
#  'learning': 40,
#  'by': 41,
#  'm': 42,
#  'artificial': 43,
#  'intelligence': 44,
#  'at': 45,
#  'manit': 46,
#  'bhopal': 47,
#  'complete': 48,
#  'pipeline': 49,
#  'evaluation': 50,
#  'engineering': 51,
#  'documentation': 52,
#  'on': 53,
#  'algorithms': 54,
#  'suitable': 55,
#  'deployed': 56,
#  'using': 57,
#  'related': 58,
#  'support': 59,
#  'questions': 60,
#  'values': 61,
#  'run': 62,
#  'use': 63,
#  'you': 64,
#  'about': 65,
#  'who': 66,
#  'developed': 67,
#  'vikas': 68,
#  'malviya': 69,
#  'pursuing': 70,
#  'purpose': 71,
#  'including': 72,
#  'preprocessing': 73,
#  'building': 74,
#  'integration': 75,
#  'cleaning': 76,
#  'feature': 77,
#  'eda': 78,
#  'user': 79,
#  'technology': 80,
#  'saving': 81,
#  'basic': 82,
#  'contain': 83,
#  'models': 84,
#  'workflow': 85,
#  'structured': 86,
#  'easy': 87,
#  'locally': 88,
#  'hosting': 89,
#  'my': 90,
#  '•': 91,
#  '–': 92,
#  'certifications': 93,
#  'microsoft': 94,
#  'azure': 95,
#  'steps': 96,
#  'includes': 97,
#  'analysis': 98,
#  'metrics': 99,
#  'web': 100,
#  'include': 101,
#  'plots': 102,
#  'imbalance': 103,
#  'accuracy': 104,
#  'may': 105,
#  'if': 106,
#  'required': 107,
#  'missing': 108,
#  'designed': 109,
#  'input': 110,
#  'provided': 111,
#  'expanded': 112,
#  'more': 113,
#  'into': 114,
#  'research': 115,
#  'datasets': 116,
#  'large': 117,
#  'intentionally': 118,
#  'postgraduate': 119,
#  'student': 120,
#  'demonstrate': 121,
#  'interactive': 122,
#  'type': 123,
#  'an': 124,
#  'system': 125,
#  'optimization': 126,
#  'interface': 127,
#  'stack': 128,
#  'python': 129,
#  'numpy': 130,
#  'pandas': 131,
#  'scikit': 132,
#  'learn': 133,
#  'matplotlib': 134,
#  'seaborn': 135,
#  'pickle': 136,
#  'git': 137,
#  'github': 138,
#  'components': 139,
#  'deep': 140,
#  'no': 141,
#  'particular': 142,
#  'focuses': 143,
#  'only': 144,
#  'classical': 145,
#  'fast': 146,
#  'execution': 147,
#  'one': 148,
#  'day': 149,
#  'build': 150,
#  'feasibility': 151,
#  'beginners': 152,
#  'entire': 153,
#  'beginner': 154,
#  'friendly': 155,
#  'understand': 156,
#  'deployable': 157,
#  'runs': 158,
#  'platforms': 159,
#  'creator': 160,
#  'name': 161,
#  'am': 162,
#  'currently': 163,
#  'maulana': 164,
#  'azad': 165,
#  'national': 166,
#  'institute': 167,
#  'educational': 168,
#  'background': 169,
#  'b': 170,
#  'electrical': 171,
#  'mits': 172,
#  'gwalior': 173,
#  'cgpa': 174,
#  '8': 175,
#  '5': 176,
#  'have': 177,
#  'holds': 178,
#  'multiple': 179,
#  'google': 180,
#  'professional': 181,
#  'engineer': 182,
#  'dp': 183,
#  '203': 184,
#  'fundamentals': 185,
#  'az': 186,
#  '900': 187,
#  'content': 188,
#  'included': 189,
#  'collection': 190,
#  'exploratory': 191,
#  'statistical': 192,
#  'insights': 193,
#  'selection': 194,
#  'generation': 195,
#  'depending': 196,
#  'logistic': 197,
#  'regression': 198,
#  'random': 199,
#  'forest': 200,
#  'vector': 201,
#  'decision': 202,
#  'tree': 203,
#  'naive': 204,
#  'bayes': 205,
#  'knn': 206,
#  'gradient': 207,
#  'boosting': 208,
#  'optional': 209,
#  'visualizations': 210,
#  'distribution': 211,
#  'correlation': 212,
#  'heatmaps': 213,
#  'class': 214,
#  'pair': 215,
#  'confusion': 216,
#  'matrix': 217,
#  'graphs': 218,
#  'publicly': 219,
#  'available': 220,
#  'from': 221,
#  'kaggle': 222,
#  'uci': 223,
#  'that': 224,
#  'open': 225,
#  'source': 226,
#  'classification': 227,
#  'tasks': 228,
#  'balanced': 229,
#  'analyzed': 230,
#  'during': 231,
#  'addressed': 232,
#  'through': 233,
#  'techniques': 234,
#  'there': 235,
#  'handled': 236,
#  'mean': 237,
#  'median': 238,
#  'imputation': 239,
#  'appropriate': 240,
#  'how': 241,
#  'after': 242,
#  'installing': 243,
#  'libraries': 244,
#  'py': 245,
#  'where': 246,
#  'also': 247,
#  'pushed': 248,
#  'other': 249,
#  'services': 250,
#  'non': 251,
#  'technical': 252,
#  'simple': 253,
#  'fields': 254,
#  'instant': 255,
#  'predictions': 256,
#  'happens': 257,
#  'when': 258,
#  'trained': 259,
#  'processes': 260,
#  'given': 261,
#  'features': 262,
#  'outputs': 263,
#  'predicted': 264,
#  'result': 265,
#  'instantly': 266,
#  'communication': 267,
#  'contact': 268,
#  'reach': 269,
#  'out': 270,
#  'vikasmlv99': 271,
#  'gmail': 272,
#  'com': 273,
#  'will': 274,
#  'face': 275,
#  'issues': 276,
#  'clarification': 277,
#  'contacting': 278,
#  'contains': 279,
#  'introduction': 280,
#  'problem': 281,
#  'statement': 282,
#  'description': 283,
#  'methodology': 284,
#  'results': 285,
#  'screenshots': 286,
#  'conclusion': 287,
#  'future': 288,
#  'scope': 289,
#  'resume': 290,
#  'absolutely': 291,
#  'portfolio': 292,
#  'academic': 293,
#  'usage': 294,
#  'general': 295,
#  'queries': 296,
#  'add': 297,
#  'hyperparameter': 298,
#  'tuning': 299,
#  'explainability': 300,
#  'shap': 301,
#  'lime': 302,
#  'api': 303,
#  'fastapi': 304,
#  'database': 305,
#  'switch': 306,
#  'different': 307,
#  'replace': 308,
#  'current': 309,
#  'any': 310,
#  'sklearn': 311,
#  'classifier': 312,
#  'while': 313,
#  'maintaining': 314,
#  'same': 315,
#  'convert': 316,
#  'adding': 317,
#  'comparative': 318,
#  'studies': 319,
#  'turned': 320,
#  'style': 321,
#  'document': 322,
#  'why': 323,
#  'section': 324,
#  'so': 325,
#  'nlp': 326,
#  'chatbots': 327,
#  'search': 328,
#  'clarity': 329,
#  'written': 330,
#  'manually': 331,
#  'resemble': 332,
#  'submission': 333,
#  'purposes': 334}

# %%
len(tokenizer.word_index)
# Out:
# 334

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[65, 1],
#  [65, 1, 2],
#  [66, 24],
#  [66, 24, 67],
#  [66, 24, 67, 4],
#  [66, 24, 67, 4, 39],
#  [66, 24, 67, 4, 39, 40],
#  [66, 24, 67, 4, 39, 40, 2],
#  [4, 2],
#  [4, 2, 24],
#  [4, 2, 24, 26],
#  [4, 2, 24, 26, 67],
#  [4, 2, 24, 26, 67, 41],
#  [4, 2, 24, 26, 67, 41, 68],
#  [4, 2, 24, 26, 67, 41, 68, 69],
#  [4, 2, 24, 26, 67, 41, 68, 69, 9],
#  [4, 2, 24, 26, 67, 41, 68, 69, 9, 119],
#  [4, 2, 24, 26, 67, 41, 68, 69, 9, 119, 120],
#  [4, 2, 24, 26, 67, 41, 68, 69, 9, 119, 120, 70],
#  [4, 2, 24, 26, 67, 41, 68, 69, 9, 119, 120, 70, 42],
#  [4, 2, 24, 26, 67, 41, 68, 69, 9, 119, 120, 70, 42, 27],
#  [4, 2, 24, 26, 67, 41, 68, 69, 9, 119, 120, 70, 42, 27, 19],
#  [4, 2, 24, 26, 67, 41, 68, 69, 9, 119, 120, 70, 42, 27, 19, 43],
#  [4, 2, 24, 26, 67, 41, 68, 69, 9, 119, 120, 70, 42, 27, 19, 43, 44],
#  [4, 2, 24, 26, 67, 41, 68, 69, 9, 119, 120, 70, 42, 27, 19, 43, 44, 45],
#  [4, 2, 24, 26, 67, 41, 68, 69, 9, 119, 120, 70, 42, 27, 19, 43, 44, 45, 46],
#  [4,
#   2,
#   24,
#   26,
#   67,
#   41,
#   68,
#   69,
#   9,
#   119,
#   120,
#   70,
#   42,
#   27,
#   19,
#   43,
#   44,
#   45,
#   46,
#   47],
#  [14, 3],
#  [14, 3, 1],
#  [14, 3, 1, 71],
#  [14, 3, 1, 71, 17],
#  [14, 3, 1, 71, 17, 4],
#  [14, 3, 1, 71, 17, 4, 11],
#  [14, 3, 1, 71, 17, 4, 11, 2],
#  [1, 71],
#  [1, 71, 17],
#  [1, 71, 17, 4],
#  [1, 71, 17, 4, 2],
#  [1, 71, 17, 4, 2, 3],
#  [1, 71, 17, 4, 2, 3, 7],
#  [1, 71, 17, 4, 2, 3, 7, 121],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9, 48],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9, 48, 20],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9, 48, 20, 7],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9, 48, 20, 7, 20],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9, 48, 20, 7, 20, 39],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9, 48, 20, 7, 20, 39, 40],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9, 48, 20, 7, 20, 39, 40, 49],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9, 48, 20, 7, 20, 39, 40, 49, 72],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9, 48, 20, 7, 20, 39, 40, 49, 72, 21],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9, 48, 20, 7, 20, 39, 40, 49, 72, 21, 73],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9, 48, 20, 7, 20, 39, 40, 49, 72, 21, 73, 5],
#  [1, 71, 17, 4, 2, 3, 7, 121, 9, 48, 20, 7, 20, 39, 40, 49, 72, 21, 73, 5, 74],
#  [1,
#   71,
#   17,
#   4,
#   2,
#   3,
#   7,
#   121,
#   9,
#   48,
#   20,
#   7,
#   20,
#   39,
#   40,
#   49,
#   72,
#   21,
#   73,
#   5,
#   74,
#   50],
#  [1,
#   71,
#   17,
#   4,
#   2,
#   3,
#   7,
#   121,
#   9,
#   48,
#   20,
#   7,
#   20,
#   39,
#   40,
#   49,
#   72,
#   21,
#   73,
#   5,
#   74,
#   50,
#   25],
#  [1,
#   71,
#   17,
#   4,
#   2,
#   3,
#   7,
#   121,
#   9,
#   48,
#   20,
#   7,
#   20,
#   39,
#   40,
#   49,
#   72,
#   21,
#   73,
#   5,
#   74,
#   50,
#   25,
#   6],
#  [1,
#   71,
#   17,
#   4,
#   2,
#   3,
#   7,
#   121,
#   9,
#   48,
#   20,
#   7,
#   20,
#   39,
#   40,
#   49,
#   72,
#   21,
#   73,
#   5,
#   74,
#   50,
#   25,
#   6,
#   122],
#  [1,
#   71,
#   17,
#   4,
#   2,
#   3,
#   7,
#   121,
#   9,
#   48,
#   20,
#   7,
#   20,
#   39,
#   40,
#   49,
#   72,
#   21,
#   73,
#   5,
#   74,
#   50,
#   25,
#   6,
#   122,
#   28],
#  [1,
#   71,
#   17,
#   4,
#   2,
#   3,
#   7,
#   121,
#   9,
#   48,
#   20,
#   7,
#   20,
#   39,
#   40,
#   49,
#   72,
#   21,
#   73,
#   5,
#   74,
#   50,
#   25,
#   6,
#   122,
#   28,
#   75],
#  [14, 123],
#  [14, 123, 17],
#  [14, 123, 17, 2],
#  [14, 123, 17, 2, 3],
#  [14, 123, 17, 2, 3, 4],
#  [29, 3],
#  [29, 3, 124],
#  [29, 3, 124, 20],
#  [29, 3, 124, 20, 7],
#  [29, 3, 124, 20, 7, 20],
#  [29, 3, 124, 20, 7, 20, 11],
#  [29, 3, 124, 20, 7, 20, 11, 125],
#  [29, 3, 124, 20, 7, 20, 11, 125, 30],
#  [21, 76],
#  [77, 51],
#  [5, 31],
#  [5, 126],
#  [5, 25],
#  [5, 25, 18],
#  [79, 127],
#  [32, 52],
#  [14, 80],
#  [14, 80, 128],
#  [14, 80, 128, 24],
#  [14, 80, 128, 24, 26],
#  [14, 80, 128, 24, 26, 33],
#  [130, 131],
#  [132, 133],
#  [134, 135],
#  [136, 12],
#  [136, 12, 5],
#  [136, 12, 5, 81],
#  [137, 138],
#  [82, 28],
#  [82, 28, 139],
#  [34, 4],
#  [34, 4, 2],
#  [34, 4, 2, 83],
#  [34, 4, 2, 83, 140],
#  [34, 4, 2, 83, 140, 40],
#  [34, 4, 2, 83, 140, 40, 84],
#  [141, 4],
#  [141, 4, 142],
#  [141, 4, 142, 2],
#  [141, 4, 142, 2, 143],
#  [141, 4, 142, 2, 143, 144],
#  [141, 4, 142, 2, 143, 144, 53],
#  [141, 4, 142, 2, 143, 144, 53, 145],
#  [141, 4, 142, 2, 143, 144, 53, 145, 11],
#  [141, 4, 142, 2, 143, 144, 53, 145, 11, 54],
#  [141, 4, 142, 2, 143, 144, 53, 145, 11, 54, 12],
#  [141, 4, 142, 2, 143, 144, 53, 145, 11, 54, 12, 146],
#  [141, 4, 142, 2, 143, 144, 53, 145, 11, 54, 12, 146, 147],
#  [141, 4, 142, 2, 143, 144, 53, 145, 11, 54, 12, 146, 147, 6],
#  [141, 4, 142, 2, 143, 144, 53, 145, 11, 54, 12, 146, 147, 6, 148],
#  [141, 4, 142, 2, 143, 144, 53, 145, 11, 54, 12, 146, 147, 6, 148, 149],
#  [141, 4, 142, 2, 143, 144, 53, 145, 11, 54, 12, 146, 147, 6, 148, 149, 150],
#  [141,
#   4,
#   142,
#   2,
#   143,
#   144,
#   53,
#   145,
#   11,
#   54,
#   12,
#   146,
#   147,
#   6,
#   148,
#   149,
#   150,
#   151],
#  [3, 1],
#  [3, 1, 2],
#  [3, 1, 2, 55],
#  [3, 1, 2, 55, 12],
#  [3, 1, 2, 55, 12, 152],
#  [10, 1],
#  [10, 1, 153],
#  [10, 1, 153, 85],
#  [10, 1, 153, 85, 3],
#  [10, 1, 153, 85, 3, 86],
#  [10, 1, 153, 85, 3, 86, 7],
#  [10, 1, 153, 85, 3, 86, 7, 15],
#  [10, 1, 153, 85, 3, 86, 7, 15, 154],
#  [10, 1, 153, 85, 3, 86, 7, 15, 154, 155],
#  [10, 1, 153, 85, 3, 86, 7, 15, 154, 155, 6],
#  [10, 1, 153, 85, 3, 86, 7, 15, 154, 155, 6, 87],
#  [10, 1, 153, 85, 3, 86, 7, 15, 154, 155, 6, 87, 7],
#  [10, 1, 153, 85, 3, 86, 7, 15, 154, 155, 6, 87, 7, 156],
#  [3, 4],
#  [3, 4, 2],
#  [3, 4, 2, 157],
#  [10, 1],
#  [10, 1, 5],
#  [10, 1, 5, 3],
#  [10, 1, 5, 3, 56],
#  [10, 1, 5, 3, 56, 57],
#  [10, 1, 5, 3, 56, 57, 18],
#  [10, 1, 5, 3, 56, 57, 18, 6],
#  [10, 1, 5, 3, 56, 57, 18, 6, 158],
#  [10, 1, 5, 3, 56, 57, 18, 6, 158, 88],
#  [10, 1, 5, 3, 56, 57, 18, 6, 158, 88, 35],
#  [10, 1, 5, 3, 56, 57, 18, 6, 158, 88, 35, 53],
#  [10, 1, 5, 3, 56, 57, 18, 6, 158, 88, 35, 53, 36],
#  [10, 1, 5, 3, 56, 57, 18, 6, 158, 88, 35, 53, 36, 89],
#  [10, 1, 5, 3, 56, 57, 18, 6, 158, 88, 35, 53, 36, 89, 159],
#  [65, 1],
#  [65, 1, 22],
#  [66, 3],
#  [66, 3, 1],
#  [66, 3, 1, 160],
#  [66, 3, 1, 160, 17],
#  [66, 3, 1, 160, 17, 4],
#  [66, 3, 1, 160, 17, 4, 2],
#  [90, 161],
#  [90, 161, 3],
#  [90, 161, 3, 68],
#  [90, 161, 3, 68, 69],
#  [90, 161, 3, 68, 69, 6],
#  [90, 161, 3, 68, 69, 6, 16],
#  [90, 161, 3, 68, 69, 6, 16, 162],
#  [90, 161, 3, 68, 69, 6, 16, 162, 163],
#  [90, 161, 3, 68, 69, 6, 16, 162, 163, 70],
#  [90, 161, 3, 68, 69, 6, 16, 162, 163, 70, 42],
#  [90, 161, 3, 68, 69, 6, 16, 162, 163, 70, 42, 27],
#  [90, 161, 3, 68, 69, 6, 16, 162, 163, 70, 42, 27, 19],
#  [90, 161, 3, 68, 69, 6, 16, 162, 163, 70, 42, 27, 19, 43],
#  [90, 161, 3, 68, 69, 6, 16, 162, 163, 70, 42, 27, 19, 43, 44],
#  [90, 161, 3, 68, 69, 6, 16, 162, 163, 70, 42, 27, 19, 43, 44, 45],
#  [90, 161, 3, 68, 69, 6, 16, 162, 163, 70, 42, 27, 19, 43, 44, 45, 164],
#  [90, 161, 3, 68, 69, 6, 16, 162, 163, 70, 42, 27, 19, 43, 44, 45, 164, 165],
#  [90,
#   161,
#   3,
#   68,
#   69,
#   6,
#   16,
#   162,
#   163,
#   70,
#   42,
#   27,
#   19,
#   43,
#   44,
#   45,
#   164,
#   165,
#   166],
#  [90,
#   161,
#   3,
#   68,
#   69,
#   6,
#   16,
#   162,
#   163,
#   70,
#   42,
#   27,
#   19,
#   43,
#   44,
#   45,
#   164,
#   165,
#   166,
#   167],
#  [90,
#   161,
#   3,
#   68,
#   69,
#   6,
#   16,
#   162,
#   163,
#   70,
#   42,
#   27,
#   19,
#   43,
#   44,
#   45,
#   164,
#   165,
#   166,
#   167,
#   17],
#  [90,
#   161,
#   3,
#   68,
#   69,
#   6,
#   16,
#   162,
#   163,
#   70,
#   42,
#   27,
#   19,
#   43,
#   44,
#   45,
#   164,
#   165,
#   166,
#   167,
#   17,
#   80],
#  [90,
#   161,
#   3,
#   68,
#   69,
#   6,
#   16,
#   162,
#   163,
#   70,
#   42,
#   27,
#   19,
#   43,
#   44,
#   45,
#   164,
#   165,
#   166,
#   167,
#   17,
#   80,
#   46],
#  [90,
#   161,
#   3,
#   68,
#   69,
#   6,
#   16,
#   162,
#   163,
#   70,
#   42,
#   27,
#   19,
#   43,
#   44,
#   45,
#   164,
#   165,
#   166,
#   167,
#   17,
#   80,
#   46,
#   47],
#  [14, 3],
#  [14, 3, 1],
#  [14, 3, 1, 168],
#  [14, 3, 1, 168, 169],
#  [14, 3, 1, 168, 169, 17],
#  [14, 3, 1, 168, 169, 17, 1],
#  [14, 3, 1, 168, 169, 17, 1, 22],
#  [91, 42],
#  [91, 42, 27],
#  [91, 42, 27, 92],
#  [91, 42, 27, 92, 43],
#  [91, 42, 27, 92, 43, 44],
#  [91, 42, 27, 92, 43, 44, 46],
#  [91, 42, 27, 92, 43, 44, 46, 47],
#  [91, 170],
#  [91, 170, 27],
#  [91, 170, 27, 92],
#  [91, 170, 27, 92, 171],
#  [91, 170, 27, 92, 171, 51],
#  [91, 170, 27, 92, 171, 51, 172],
#  [91, 170, 27, 92, 171, 51, 172, 173],
#  [91, 170, 27, 92, 171, 51, 172, 173, 174],
#  [91, 170, 27, 92, 171, 51, 172, 173, 174, 175],
#  [91, 170, 27, 92, 171, 51, 172, 173, 174, 175, 176],
#  [34, 1],
#  [34, 1, 22],
#  [34, 1, 22, 177],
#  [34, 1, 22, 177, 11],
#  [34, 1, 22, 177, 11, 58],
#  [34, 1, 22, 177, 11, 58, 93],
#  [10, 1],
#  [10, 1, 22],
#  [10, 1, 22, 178],
#  [10, 1, 22, 178, 179],
#  [10, 1, 22, 178, 179, 93],
#  [10, 1, 22, 178, 179, 93, 72],
#  [180, 36],
#  [180, 36, 181],
#  [180, 36, 181, 21],
#  [180, 36, 181, 21, 182],
#  [94, 95],
#  [94, 95, 183],
#  [94, 95, 183, 184],
#  [94, 95],
#  [94, 95, 185],
#  [94, 95, 185, 186],
#  [94, 95, 185, 186, 187],
#  [2, 85],
#  [2, 85, 6],
#  [2, 85, 6, 188],
#  [14, 96],
#  [14, 96, 37],
#  [14, 96, 37, 189],
#  [14, 96, 37, 189, 19],
#  [14, 96, 37, 189, 19, 4],
#  [14, 96, 37, 189, 19, 4, 11],
#  [14, 96, 37, 189, 19, 4, 11, 2],
#  [1, 2],
#  [1, 2, 97],
#  [21, 190],
#  [21, 76],
#  [191, 21],
#  [191, 21, 98],
#  [192, 193],
#  [77, 51],
#  [5, 194],
#  [5, 31],
#  [50, 99],
#  [81, 1],
#  [81, 1, 5],
#  [74, 9],
#  [74, 9, 18],
#  [74, 9, 18, 100],
#  [74, 9, 18, 100, 38],
#  [32, 195],
#  [14, 54],
#  [14, 54, 37],
#  [14, 54, 37, 33],
#  [14, 54, 37, 33, 19],
#  [14, 54, 37, 33, 19, 4],
#  [14, 54, 37, 33, 19, 4, 2],
#  [196, 53],
#  [196, 53, 1],
#  [196, 53, 1, 13],
#  [197, 198],
#  [199, 200],
#  [59, 201],
#  [59, 201, 39],
#  [202, 203],
#  [204, 205],
#  [207, 208],
#  [207, 208, 209],
#  [34, 1],
#  [34, 1, 2],
#  [34, 1, 2, 101],
#  [34, 1, 2, 101, 210],
#  [10, 29],
#  [10, 29, 97],
#  [211, 102],
#  [212, 213],
#  [214, 103],
#  [214, 103, 98],
#  [215, 102],
#  [216, 217],
#  [104, 218],
#  [13, 58],
#  [13, 58, 60],
#  [14, 13],
#  [14, 13, 24],
#  [14, 13, 24, 26],
#  [14, 13, 24, 26, 33],
#  [14, 13, 24, 26, 33, 19],
#  [14, 13, 24, 26, 33, 19, 1],
#  [14, 13, 24, 26, 33, 19, 1, 2],
#  [9, 219],
#  [9, 219, 220],
#  [9, 219, 220, 13],
#  [9, 219, 220, 13, 221],
#  [9, 219, 220, 13, 221, 222],
#  [9, 219, 220, 13, 221, 222, 223],
#  [9, 219, 220, 13, 221, 222, 223, 224],
#  [9, 219, 220, 13, 221, 222, 223, 224, 3],
#  [9, 219, 220, 13, 221, 222, 223, 224, 3, 225],
#  [9, 219, 220, 13, 221, 222, 223, 224, 3, 225, 226],
#  [9, 219, 220, 13, 221, 222, 223, 224, 3, 225, 226, 6],
#  [9, 219, 220, 13, 221, 222, 223, 224, 3, 225, 226, 6, 55],
#  [9, 219, 220, 13, 221, 222, 223, 224, 3, 225, 226, 6, 55, 12],
#  [9, 219, 220, 13, 221, 222, 223, 224, 3, 225, 226, 6, 55, 12, 11],
#  [9, 219, 220, 13, 221, 222, 223, 224, 3, 225, 226, 6, 55, 12, 11, 227],
#  [9, 219, 220, 13, 221, 222, 223, 224, 3, 225, 226, 6, 55, 12, 11, 227, 228],
#  [3, 1],
#  [3, 1, 13],
#  [3, 1, 13, 229],
#  [1, 13],
#  [1, 13, 105],
#  [1, 13, 105, 83],
#  [1, 13, 105, 83, 103],
#  [1, 13, 105, 83, 103, 4],
#  [1, 13, 105, 83, 103, 4, 24],
#  [1, 13, 105, 83, 103, 4, 24, 26],
#  [1, 13, 105, 83, 103, 4, 24, 26, 230],
#  [1, 13, 105, 83, 103, 4, 24, 26, 230, 231],
#  [1, 13, 105, 83, 103, 4, 24, 26, 230, 231, 78],
#  [1, 13, 105, 83, 103, 4, 24, 26, 230, 231, 78, 6],
#  [1, 13, 105, 83, 103, 4, 24, 26, 230, 231, 78, 6, 232],
#  [1, 13, 105, 83, 103, 4, 24, 26, 230, 231, 78, 6, 232, 233],
#  [1, 13, 105, 83, 103, 4, 24, 26, 230, 231, 78, 6, 232, 233, 11],
#  [1, 13, 105, 83, 103, 4, 24, 26, 230, 231, 78, 6, 232, 233, 11, 234],
#  [1, 13, 105, 83, 103, 4, 24, 26, 230, 231, 78, 6, 232, 233, 11, 234, 106],
#  [1,
#   13,
#   105,
#   83,
#   103,
#   4,
#   24,
#   26,
#   230,
#   231,
#   78,
#   6,
#   232,
#   233,
#   11,
#   234,
#   106,
#   107],
#  [37, 235],
#  [37, 235, 108],
#  [37, 235, 108, 61],
#  [37, 235, 108, 61, 19],
#  [37, 235, 108, 61, 19, 1],
#  [37, 235, 108, 61, 19, 1, 13],
#  [108, 61],
#  [108, 61, 37],
#  [108, 61, 37, 236],
#  [108, 61, 37, 236, 57],
#  [108, 61, 37, 236, 57, 237],
#  [108, 61, 37, 236, 57, 237, 238],
#  [108, 61, 37, 236, 57, 237, 238, 239],
#  [108, 61, 37, 236, 57, 237, 238, 239, 35],
#  [108, 61, 37, 236, 57, 237, 238, 239, 35, 240],
#  [108, 61, 37, 236, 57, 237, 238, 239, 35, 240, 73],
#  [108, 61, 37, 236, 57, 237, 238, 239, 35, 240, 73, 96],
#  [25, 58],
#  [25, 58, 60],
#  [241, 8],
#  [241, 8, 16],
#  [241, 8, 16, 62],
#  [241, 8, 16, 62, 4],
#  [241, 8, 16, 62, 4, 2],
#  [242, 243],
#  [242, 243, 1],
#  [242, 243, 1, 107],
#  [242, 243, 1, 107, 244],
#  [242, 243, 1, 107, 244, 63],
#  [18, 62],
#  [18, 62, 38],
#  [18, 62, 38, 245],
#  [246, 3],
#  [246, 3, 1],
#  [246, 3, 1, 5],
#  [246, 3, 1, 5, 56],
#  [1, 5],
#  [1, 5, 3],
#  [1, 5, 3, 56],
#  [1, 5, 3, 56, 88],
#  [1, 5, 3, 56, 88, 57],
#  [1, 5, 3, 56, 88, 57, 18],
#  [1, 5, 3, 56, 88, 57, 18, 28],
#  [1, 5, 3, 56, 88, 57, 18, 28, 29],
#  [1, 5, 3, 56, 88, 57, 18, 28, 29, 8],
#  [1, 5, 3, 56, 88, 57, 18, 28, 29, 8, 247],
#  [1, 5, 3, 56, 88, 57, 18, 28, 29, 8, 247, 15],
#  [1, 5, 3, 56, 88, 57, 18, 28, 29, 8, 247, 15, 248],
#  [1, 5, 3, 56, 88, 57, 18, 28, 29, 8, 247, 15, 248, 7],
#  [1, 5, 3, 56, 88, 57, 18, 28, 29, 8, 247, 15, 248, 7, 18],
#  [1, 5, 3, 56, 88, 57, 18, 28, 29, 8, 247, 15, 248, 7, 18, 36],
#  [1, 5, 3, 56, 88, 57, 18, 28, 29, 8, 247, 15, 248, 7, 18, 36, 35],
#  [1, 5, 3, 56, 88, 57, 18, 28, 29, 8, 247, 15, 248, 7, 18, 36, 35, 249],
#  [1, 5, 3, 56, 88, 57, 18, 28, 29, 8, 247, 15, 248, 7, 18, 36, 35, 249, 89],
#  [1,
#   5,
#   3,
#   56,
#   88,
#   57,
#   18,
#   28,
#   29,
#   8,
#   247,
#   15,
#   248,
#   7,
#   18,
#   36,
#   35,
#   249,
#   89,
#   250],
#  [8, 9],
#  [8, 9, 251],
#  [8, 9, 251, 252],
#  [8, 9, 251, 252, 79],
#  [8, 9, 251, 252, 79, 62],
#  [8, 9, 251, 252, 79, 62, 1],
#  [8, 9, 251, 252, 79, 62, 1, 38],
#  [10, 1],
#  [10, 1, 28],
#  [10, 1, 28, 3],
#  [10, 1, 28, 3, 109],
#  [10, 1, 28, 3, 109, 7],
#  [10, 1, 28, 3, 109, 7, 15],
#  [10, 1, 28, 3, 109, 7, 15, 253],
#  [10, 1, 28, 3, 109, 7, 15, 253, 6],
#  [10, 1, 28, 3, 109, 7, 15, 253, 6, 87],
#  [10, 1, 28, 3, 109, 7, 15, 253, 6, 87, 7],
#  [10, 1, 28, 3, 109, 7, 15, 253, 6, 87, 7, 63],
#  [10, 1, 28, 3, 109, 7, 15, 253, 6, 87, 7, 63, 30],
#  [10, 1, 28, 3, 109, 7, 15, 253, 6, 87, 7, 63, 30, 110],
#  [10, 1, 28, 3, 109, 7, 15, 253, 6, 87, 7, 63, 30, 110, 254],
#  [10, 1, 28, 3, 109, 7, 15, 253, 6, 87, 7, 63, 30, 110, 254, 6],
#  [10, 1, 28, 3, 109, 7, 15, 253, 6, 87, 7, 63, 30, 110, 254, 6, 255],
#  [10, 1, 28, 3, 109, 7, 15, 253, 6, 87, 7, 63, 30, 110, 254, 6, 255, 256],
#  [14, 257],
#  [14, 257, 258],
#  [14, 257, 258, 16],
#  [14, 257, 258, 16, 110],
#  [14, 257, 258, 16, 110, 1],
#  [14, 257, 258, 16, 110, 1, 61],
#  [1, 259],
#  [1, 259, 11],
#  [1, 259, 11, 5],
#  [1, 259, 11, 5, 260],
#  [1, 259, 11, 5, 260, 1],
#  [1, 259, 11, 5, 260, 1, 261],
#  [1, 259, 11, 5, 260, 1, 261, 262],
#  [1, 259, 11, 5, 260, 1, 261, 262, 6],
#  [1, 259, 11, 5, 260, 1, 261, 262, 6, 263],
#  [1, 259, 11, 5, 260, 1, 261, 262, 6, 263, 1],
#  [1, 259, 11, 5, 260, 1, 261, 262, 6, 263, 1, 264],
#  [1, 259, 11, 5, 260, 1, 261, 262, 6, 263, 1, 264, 265],
#  [1, 259, 11, 5, 260, 1, 261, 262, 6, 263, 1, 264, 265, 266],
#  [59, 6],
#  [59, 6, 267],
#  [8, 16],
#  [8, 16, 268],
#  [8, 16, 268, 1],
#  [8, 16, 268, 1, 22],
#  [8, 16, 268, 1, 22, 12],
#  [8, 16, 268, 1, 22, 12, 60],
#  [10, 64],
#  [10, 64, 8],
#  [10, 64, 8, 269],
#  [10, 64, 8, 269, 270],
#  [10, 64, 8, 269, 270, 45],
#  [10, 64, 8, 269, 270, 45, 271],
#  [10, 64, 8, 269, 270, 45, 271, 272],
#  [10, 64, 8, 269, 270, 45, 271, 272, 273],
#  [274, 59],
#  [274, 59, 15],
#  [274, 59, 15, 111],
#  [274, 59, 15, 111, 106],
#  [274, 59, 15, 111, 106, 16],
#  [274, 59, 15, 111, 106, 16, 275],
#  [274, 59, 15, 111, 106, 16, 275, 276],
#  [82, 277],
#  [82, 277, 8],
#  [82, 277, 8, 15],
#  [82, 277, 8, 15, 111],
#  [82, 277, 8, 15, 111, 41],
#  [82, 277, 8, 15, 111, 41, 278],
#  [82, 277, 8, 15, 111, 41, 278, 1],
#  [82, 277, 8, 15, 111, 41, 278, 1, 22],
#  [2, 52],
#  [34, 4],
#  [34, 4, 11],
#  [34, 4, 11, 2],
#  [34, 4, 11, 2, 101],
#  [34, 4, 11, 2, 101, 9],
#  [34, 4, 11, 2, 101, 9, 48],
#  [34, 4, 11, 2, 101, 9, 48, 32],
#  [10, 1],
#  [10, 1, 32],
#  [10, 1, 32, 279],
#  [281, 282],
#  [13, 283],
#  [5, 49],
#  [285, 104],
#  [286, 17],
#  [286, 17, 100],
#  [286, 17, 100, 38],
#  [287, 6],
#  [287, 6, 288],
#  [287, 6, 288, 289],
#  [8, 16],
#  [8, 16, 63],
#  [8, 16, 63, 4],
#  [8, 16, 63, 4, 2],
#  [8, 16, 63, 4, 2, 12],
#  [8, 16, 63, 4, 2, 12, 90],
#  [8, 16, 63, 4, 2, 12, 90, 290],
#  [291, 4],
#  [291, 4, 3],
#  [291, 4, 3, 9],
#  [291, 4, 3, 9, 48],
#  [291, 4, 3, 9, 48, 20],
#  [291, 4, 3, 9, 48, 20, 7],
#  [291, 4, 3, 9, 48, 20, 7, 20],
#  [291, 4, 3, 9, 48, 20, 7, 20, 2],
#  [291, 4, 3, 9, 48, 20, 7, 20, 2, 55],
#  [291, 4, 3, 9, 48, 20, 7, 20, 2, 55, 12],
#  [291, 4, 3, 9, 48, 20, 7, 20, 2, 55, 12, 292],
#  [291, 4, 3, 9, 48, 20, 7, 20, 2, 55, 12, 292, 6],
#  [291, 4, 3, 9, 48, 20, 7, 20, 2, 55, 12, 292, 6, 293],
#  [291, 4, 3, 9, 48, 20, 7, 20, 2, 55, 12, 292, 6, 293, 294],
#  [295, 2],
#  [295, 2, 296],
#  [8, 4],
#  [8, 4, 2],
#  [8, 4, 2, 15],
#  [8, 4, 2, 15, 112],
#  [10, 64],
#  [10, 64, 8],
#  [10, 64, 8, 297],
#  [298, 299],
#  [113, 54],
#  [300, 301],
#  [300, 301, 302],
#  [303, 25],
#  [303, 25, 30],
#  [303, 25, 30, 304],
#  [36, 25],
#  [305, 75],
#  [8, 16],
#  [8, 16, 306],
#  [8, 16, 306, 7],
#  [8, 16, 306, 7, 9],
#  [8, 16, 306, 7, 9, 307],
#  [8, 16, 306, 7, 9, 307, 5],
#  [64, 105],
#  [64, 105, 308],
#  [64, 105, 308, 1],
#  [64, 105, 308, 1, 309],
#  [64, 105, 308, 1, 309, 5],
#  [64, 105, 308, 1, 309, 5, 30],
#  [64, 105, 308, 1, 309, 5, 30, 310],
#  [64, 105, 308, 1, 309, 5, 30, 310, 311],
#  [64, 105, 308, 1, 309, 5, 30, 310, 311, 312],
#  [64, 105, 308, 1, 309, 5, 30, 310, 311, 312, 313],
#  [64, 105, 308, 1, 309, 5, 30, 310, 311, 312, 313, 314],
#  [64, 105, 308, 1, 309, 5, 30, 310, 311, 312, 313, 314, 1],
#  [64, 105, 308, 1, 309, 5, 30, 310, 311, 312, 313, 314, 1, 315],
#  [64, 105, 308, 1, 309, 5, 30, 310, 311, 312, 313, 314, 1, 315, 49],
#  [8, 16],
#  [8, 16, 316],
#  [8, 16, 316, 4],
#  [8, 16, 316, 4, 114],
#  [8, 16, 316, 4, 114, 9],
#  [8, 16, 316, 4, 114, 9, 115],
#  [8, 16, 316, 4, 114, 9, 115, 2],
#  [10, 41],
#  [10, 41, 317],
#  [10, 41, 317, 113],
#  [10, 41, 317, 113, 116],
#  [10, 41, 317, 113, 116, 50],
#  [10, 41, 317, 113, 116, 50, 99],
#  [10, 41, 317, 113, 116, 50, 99, 6],
#  [10, 41, 317, 113, 116, 50, 99, 6, 318],
#  [10, 41, 317, 113, 116, 50, 99, 6, 318, 319],
#  [10, 41, 317, 113, 116, 50, 99, 6, 318, 319, 29],
#  [10, 41, 317, 113, 116, 50, 99, 6, 318, 319, 29, 8],
#  [10, 41, 317, 113, 116, 50, 99, 6, 318, 319, 29, 8, 15],
#  [10, 41, 317, 113, 116, 50, 99, 6, 318, 319, 29, 8, 15, 320],
#  [10, 41, 317, 113, 116, 50, 99, 6, 318, 319, 29, 8, 15, 320, 114],
#  [10, 41, 317, 113, 116, 50, 99, 6, 318, 319, 29, 8, 15, 320, 114, 9],
#  [10, 41, 317, 113, 116, 50, 99, 6, 318, 319, 29, 8, 15, 320, 114, 9, 115],
#  [10,
#   41,
#   317,
#   113,
#   116,
#   50,
#   99,
#   6,
#   318,
#   319,
#   29,
#   8,
#   15,
#   320,
#   114,
#   9,
#   115,
#   321],
#  [10,
#   41,
#   317,
#   113,
#   116,
#   50,
#   99,
#   6,
#   318,
#   319,
#   29,
#   8,
#   15,
#   320,
#   114,
#   9,
#   115,
#   321,
#   322],
#  [323, 3],
#  [323, 3, 1],
#  [323, 3, 1, 23],
#  [323, 3, 1, 23, 324],
#  [323, 3, 1, 23, 324, 325],
#  [323, 3, 1, 23, 324, 325, 117],
#  [1, 23],
#  [1, 23, 13],
#  [1, 23, 13, 3],
#  [1, 23, 13, 3, 118],
#  [1, 23, 13, 3, 118, 112],
#  [1, 23, 13, 3, 118, 112, 7],
#  [1, 23, 13, 3, 118, 112, 7, 15],
#  [1, 23, 13, 3, 118, 112, 7, 15, 33],
#  [1, 23, 13, 3, 118, 112, 7, 15, 33, 12],
#  [326, 31],
#  [23, 327],
#  [328, 84],
#  [2, 329],
#  [3, 4],
#  [3, 4, 23],
#  [3, 4, 23, 330],
#  [3, 4, 23, 330, 331],
#  [10, 4],
#  [10, 4, 23],
#  [10, 4, 23, 3],
#  [10, 4, 23, 3, 118],
#  [10, 4, 23, 3, 118, 109],
#  [10, 4, 23, 3, 118, 109, 7],
#  [10, 4, 23, 3, 118, 109, 7, 332],
#  [10, 4, 23, 3, 118, 109, 7, 332, 117],
#  [10, 4, 23, 3, 118, 109, 7, 332, 117, 86],
#  [10, 4, 23, 3, 118, 109, 7, 332, 117, 86, 23],
#  [10, 4, 23, 3, 118, 109, 7, 332, 117, 86, 23, 116],
#  [10, 4, 23, 3, 118, 109, 7, 332, 117, 86, 23, 116, 12],
#  [10, 4, 23, 3, 118, 109, 7, 332, 117, 86, 23, 116, 12, 5],
#  [10, 4, 23, 3, 118, 109, 7, 332, 117, 86, 23, 116, 12, 5, 31],
#  [10, 4, 23, 3, 118, 109, 7, 332, 117, 86, 23, 116, 12, 5, 31, 35],
#  [10, 4, 23, 3, 118, 109, 7, 332, 117, 86, 23, 116, 12, 5, 31, 35, 333],
#  [10, 4, 23, 3, 118, 109, 7, 332, 117, 86, 23, 116, 12, 5, 31, 35, 333, 334]]

# %%
max_len = max([len(x) for x in input_sequences])

# %%
max_len
# Out:
# 27

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (608, 26)

# %%
y.shape
# Out:
# (608,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=335)

# %%
y.shape
# Out:
# (608, 335)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()
model.add(Embedding(len(tokenizer.word_index) + 1, 100))
model.add(LSTM(150, return_sequences=True))
model.add(LSTM(150))
model.add(Dense(len(tokenizer.word_index) + 1, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 4s 81ms/step - accuracy: 0.0238 - loss: 5.7685
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.0334 - loss: 5.3306
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.0466 - loss: 5.2705
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.0453 - loss: 5.2626
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.0694 - loss: 5.0896
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.0688 - loss: 5.0206
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.0521 - loss: 5.0545
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.0744 - loss: 4.8901
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.0598 - loss: 4.8046
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.0885 - loss: 4.7542
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.0861 - loss: 4.6967
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.0715 - loss: 4.6578
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.0831 - loss: 4.6086
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.0843 - loss: 4.4426
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.0810 - loss: 4.4012
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.0885 - loss: 4.3746
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.1090 - loss: 4.2665
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.1101 - loss: 4.2286
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.1100 - loss: 4.1325
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.1374 - loss: 4.0772
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.1362 - loss: 4.0352
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.1463 - loss: 3.9491
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.1560 - loss: 3.8433
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1601 - loss: 3.8017
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.1565 - loss: 3.7269
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.1568 - loss: 3.6967
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.1800 - loss: 3.6003
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.1857 - loss: 3.5079
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.1966 - loss: 3.3669
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.2095 - loss: 3.4077
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.2140 - loss: 3.2303
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.2585 - loss: 3.1785
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.2655 - loss: 3.1050
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.2879 - loss: 3.0241
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.2774 - loss: 2.9726
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.3003 - loss: 2.9180
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3205 - loss: 2.8228
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.3205 - loss: 2.8227
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.3434 - loss: 2.7656
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.3828 - loss: 2.6427
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4347 - loss: 2.5418
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.4152 - loss: 2.5171
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.4860 - loss: 2.4056
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.4803 - loss: 2.3536
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5357 - loss: 2.2797
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5422 - loss: 2.2795
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.5281 - loss: 2.1952
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.5605 - loss: 2.1708
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.5583 - loss: 2.0657
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.5976 - loss: 2.0435
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.6490 - loss: 1.9354
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6865 - loss: 1.8532
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.6627 - loss: 1.8502
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.6865 - loss: 1.7173
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6635 - loss: 1.7460
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7438 - loss: 1.5738
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.7302 - loss: 1.6489
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.7136 - loss: 1.6629
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.7520 - loss: 1.5231
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.7455 - loss: 1.4844
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.7600 - loss: 1.4409
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.7165 - loss: 1.4707
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.7619 - loss: 1.4583
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.7654 - loss: 1.3801
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.8059 - loss: 1.3011
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.7768 - loss: 1.2701
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.7922 - loss: 1.2771
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.7557 - loss: 1.2958
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.7821 - loss: 1.2080
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8216 - loss: 1.1052
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8145 - loss: 1.1109
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7988 - loss: 1.1225
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.8039 - loss: 1.0763
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.8134 - loss: 1.0417
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.8143 - loss: 1.0206
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.8041 - loss: 1.0301
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8214 - loss: 0.9429
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8386 - loss: 0.9310
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.8437 - loss: 0.8871
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8445 - loss: 0.8532
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8225 - loss: 0.9467
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8549 - loss: 0.8074
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8256 - loss: 0.8355
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.8342 - loss: 0.8246
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.8279 - loss: 0.7712
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.8444 - loss: 0.8241
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8466 - loss: 0.7755
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.8723 - loss: 0.7216
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.8532 - loss: 0.7326
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8409 - loss: 0.7653
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.8731 - loss: 0.7204
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.8734 - loss: 0.6781
# Epoch 93/100
#  2/19 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8672 - loss: 0.5875

# %%
import numpy as np
import time
text = "my name is"
for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
